# %% [markdown]
# <a href="https://colab.research.google.com/github/juancabernal/challengeAlura/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
# Calcular ingreso total por tienda
ingreso_tienda_1 = tienda["Precio"].sum()
ingreso_tienda_2 = tienda2["Precio"].sum()
ingreso_tienda_3 = tienda3["Precio"].sum()
ingreso_tienda_4 = tienda4["Precio"].sum()

# Mostrar resultados
print(f"Ingreso total Tienda 1: ${ingreso_tienda_1:,.2f}")
print(f"Ingreso total Tienda 2: ${ingreso_tienda_2:,.2f}")
print(f"Ingreso total Tienda 3: ${ingreso_tienda_3:,.2f}")
print(f"Ingreso total Tienda 4: ${ingreso_tienda_4:,.2f}")
# Out:
# Ingreso total Tienda 1: $1,150,880,400.00
# Ingreso total Tienda 2: $1,116,343,500.00
# Ingreso total Tienda 3: $1,098,019,600.00
# Ingreso total Tienda 4: $1,038,375,700.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Limpiar nombres de columnas de todas las tiendas
tienda.columns = tienda.columns.str.strip()
tienda2.columns = tienda2.columns.str.strip()
tienda3.columns = tienda3.columns.str.strip()
tienda4.columns = tienda4.columns.str.strip()

ventas_categoria_1 = tienda["Categoría del Producto"].value_counts()
ventas_categoria_2 = tienda2["Categoría del Producto"].value_counts()
ventas_categoria_3 = tienda3["Categoría del Producto"].value_counts()
ventas_categoria_4 = tienda4["Categoría del Producto"].value_counts()

print("Tienda 1 - Ventas por categoría:")
print(ventas_categoria_1, end="\n\n")

print("Tienda 2 - Ventas por categoría:")
print(ventas_categoria_2, end="\n\n")

print("Tienda 3 - Ventas por categoría:")
print(ventas_categoria_3, end="\n\n")

print("Tienda 4 - Ventas por categoría:")
print(ventas_categoria_4, end="\n\n")
# Out:
# Tienda 1 - Ventas por categoría:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
#
# Tienda 2 - Ventas por categoría:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
#
# Tienda 3 - Ventas por categoría:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Limpia espacios/tabs de los nombres de columnas
tienda.columns = tienda.columns.str.strip()
tienda2.columns = tienda2.columns.str.strip()
tienda3.columns = tienda3.columns.str.strip()
tienda4.columns = tienda4.columns.str.strip()

# Calcula promedio de calificaciones
promedio_calif_1 = tienda["Calificación"].mean()
promedio_calif_2 = tienda2["Calificación"].mean()
promedio_calif_3 = tienda3["Calificación"].mean()
promedio_calif_4 = tienda4["Calificación"].mean()

# Mostrar resultados
print(f"Calificación promedio Tienda 1: {promedio_calif_1:.2f}")
print(f"Calificación promedio Tienda 2: {promedio_calif_2:.2f}")
print(f"Calificación promedio Tienda 3: {promedio_calif_3:.2f}")
print(f"Calificación promedio Tienda 4: {promedio_calif_4:.2f}")
# Out:
# Calificación promedio Tienda 1: 3.98
# Calificación promedio Tienda 2: 4.04
# Calificación promedio Tienda 3: 4.05
# Calificación promedio Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Limpiar nombres de columnas
tienda.columns = tienda.columns.str.strip()
tienda2.columns = tienda2.columns.str.strip()
tienda3.columns = tienda3.columns.str.strip()
tienda4.columns = tienda4.columns.str.strip()


# Productos más y menos vendidos
mas_vendidos_1 = tienda["Producto"].value_counts().head(5)
menos_vendidos_1 = tienda["Producto"].value_counts().tail(5)

mas_vendidos_2 = tienda2["Producto"].value_counts().head(5)
menos_vendidos_2 = tienda2["Producto"].value_counts().tail(5)

mas_vendidos_3 = tienda3["Producto"].value_counts().head(5)
menos_vendidos_3 = tienda3["Producto"].value_counts().tail(5)

mas_vendidos_4 = tienda4["Producto"].value_counts().head(5)
menos_vendidos_4 = tienda4["Producto"].value_counts().tail(5)


import matplotlib.pyplot as plt

def graficar_top_bottom(mas, menos, titulo):
    fig, axs = plt.subplots(1, 2, figsize=(14, 5))
    mas.plot(kind='bar', ax=axs[0], color='green')
    menos.plot(kind='bar', ax=axs[1], color='red')
    axs[0].set_title(f"Top productos más vendidos - {titulo}")
    axs[1].set_title(f"Productos menos vendidos - {titulo}")
    axs[0].set_ylabel("Cantidad Vendida")
    axs[1].set_ylabel("Cantidad Vendida")
    plt.tight_layout()
    plt.show()

# Graficar cada tienda
graficar_top_bottom(mas_vendidos_1, menos_vendidos_1, "Tienda 1")
graficar_top_bottom(mas_vendidos_2, menos_vendidos_2, "Tienda 2")
graficar_top_bottom(mas_vendidos_3, menos_vendidos_3, "Tienda 3")
graficar_top_bottom(mas_vendidos_4, menos_vendidos_4, "Tienda 4")

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Eliminar espacios o caracteres invisibles de los nombres de columnas
tienda.columns = tienda.columns.str.strip()
tienda2.columns = tienda2.columns.str.strip()
tienda3.columns = tienda3.columns.str.strip()
tienda4.columns = tienda4.columns.str.strip()


# Calcular el costo de envío promedio por tienda
envio_prom_1 = tienda["Costo de envío"].mean()
envio_prom_2 = tienda2["Costo de envío"].mean()
envio_prom_3 = tienda3["Costo de envío"].mean()
envio_prom_4 = tienda4["Costo de envío"].mean()

# Mostrar los resultados
print(f"Costo de envío promedio - Tienda 1: ${envio_prom_1:.2f}")
print(f"Costo de envío promedio - Tienda 2: ${envio_prom_2:.2f}")
print(f"Costo de envío promedio - Tienda 3: ${envio_prom_3:.2f}")
print(f"Costo de envío promedio - Tienda 4: ${envio_prom_4:.2f}")
# Out:
# Costo de envío promedio - Tienda 1: $26018.61
# Costo de envío promedio - Tienda 2: $25216.24
# Costo de envío promedio - Tienda 3: $24805.68
# Costo de envío promedio - Tienda 4: $23459.46

# %% [markdown]
# # 6.Gráficos

# %%
import matplotlib.pyplot as plt

# Calcular ingresos por tienda
ingresos = [
    tienda["Precio"].sum(),
    tienda2["Precio"].sum(),
    tienda3["Precio"].sum(),
    tienda4["Precio"].sum()
]

nombres_tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

plt.figure(figsize=(8, 5))
plt.bar(nombres_tiendas, ingresos, color='skyblue')
plt.title("Ingresos Totales por Tienda")
plt.ylabel("Ingresos en USD")
plt.xlabel("Tienda")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()


# Calcular calificaciones promedio
promedios_calificaciones = [
    tienda["Calificación"].mean(),
    tienda2["Calificación"].mean(),
    tienda3["Calificación"].mean(),
    tienda4["Calificación"].mean()
]

plt.figure(figsize=(8, 5))
plt.plot(nombres_tiendas, promedios_calificaciones, marker='o', color='green', linestyle='--')
plt.title("Calificación Promedio por Tienda")
plt.ylabel("Puntuación Promedio (de 0 a 5)")
plt.xlabel("Tienda")
plt.ylim(0, 5)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()


categorias_1 = tienda["Categoría del Producto"].value_counts().head(5)  # top 5 para simplificar

plt.figure(figsize=(7, 7))
plt.pie(categorias_1, labels=categorias_1.index, autopct='%1.1f%%', startangle=140)
plt.title("Distribución de Categorías - Tienda 1")
plt.axis('equal')  # Círculo perfecto
plt.tight_layout()
plt.show()

# %% [markdown]
# #Análisis del desempeño geográfico

# %%
import pandas as pd

# Cargar los datos
urls = [
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"
]

tiendas = []
for i, url in enumerate(urls):
    df = pd.read_csv(url)
    df["Tienda"] = f"Tienda {i+1}"
    tiendas.append(df)

df_general = pd.concat(tiendas, ignore_index=True)

# Verificar nombres de columnas
print(df_general.columns)

# Renombrar columnas si tienen espacios o caracteres especiales
df_general.columns = df_general.columns.str.strip()

# Asegurarse de que las columnas de latitud y longitud estén en formato numérico
df_general["lat"] = pd.to_numeric(df_general["lat"], errors='coerce')
df_general["lon"] = pd.to_numeric(df_general["lon"], errors='coerce')

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df_general, x="lon", y="lat",
    hue="Tienda", alpha=0.6, palette="tab10"
)
plt.title("Distribución Geográfica de Ventas por Tienda")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.grid(True)
plt.legend(title="Tienda")
plt.show()


import folium
from folium.plugins import HeatMap

# Crear un mapa base
m = folium.Map(location=[df_general["lat"].mean(), df_general["lon"].mean()], zoom_start=4)

# Añadir capa de calor
heat_data = df_general[["lat", "lon"]].dropna().values.tolist()
HeatMap(heat_data, radius=8).add_to(m)

m  # Muestra el mapa
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon', 'Tienda'],
#       dtype='object')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...

# %% [markdown]
# #INFORME FINAL
# ##Introducción
# El presente análisis tiene como propósito asesorar al Sr. Juan sobre cuál tienda representa la mejor opción para vender sus productos e identificar la tienda con el peor desempeño general. Para ello, se examinaron los datos de cuatro tiendas distintas con base en factores clave como: ingresos generados, tipos de productos más y menos vendidos, calificaciones otorgadas por los clientes, costos de envío y comportamiento general de ventas. A partir de estos análisis, se presentan visualizaciones y una recomendación fundamentada para facilitar una toma de decisiones informada.
#
# ##Análisis de Resultados
# ###Ingresos Totales por Tienda
# Mediante la suma de los valores de la columna Precio, se obtuvo el ingreso total de cada tienda. La Tienda 1 lidera con el mayor ingreso, seguida de la Tienda 2, lo cual indica un alto volumen de ventas y/o productos de mayor valor comercial. Por otro lado, la Tienda 4 es la que generó los ingresos más bajos, lo que podría deberse a una baja rotación de productos, precios bajos o una combinación de ambos. Esto la posiciona como una candidata para ser vendida.
#
# **Visualización sugerida: Gráfico de barras de ingresos por tienda.**
#
# ###Distribución de Categorías de Productos
# Al agrupar por la columna de categoría y contar la frecuencia, se observó que algunas tiendas tienen mayor diversidad o enfoque en ciertos productos. Por ejemplo:
#
# Todas las tiendas muestran una fuerte concentración en muebles y electrónicos. Por otro lado, entre las menos vendidas se encuentran los artículos para el hogar, los instrumentos musicales y los libros
#
# **Visualización sugerida: Gráfico circular con las 5 categorías más vendidas de Tienda 1.**
#
# ###Calificaciones Promedio por Tienda
# Las opiniones de los clientes son fundamentales. La tienda con mejor calificación promedio fue la Tienda 3, seguida muy de cerca por la Tienda 2. Esto refleja altos niveles de satisfacción del cliente y posiblemente buena atención postventa.
# Del mismo modo, la tienda con peor rendimiento fue la número 1, seguida de la 4.
#
# **Visualización sugerida: Gráfico de líneas con las calificaciones promedio por tienda.**
#
# ###Productos Más y Menos Vendidos
# Entre los produtos más vendidos se encuentran los microondas, "Iniciando en programación", kit de bancas y cama box.
# Entre los menos vendidos se pueden visualizar la guitarra eléctrica, "bloques de instrucción", juegos de mesa y celular ABXY.
#
# **Visualización opcional: Barras horizontales con productos más/menos vendidos por tienda.**
#
# ###Costo de Envío Promedio
# Este factor impacta directamente la experiencia del cliente. La Tienda 4 tuvo el costo de envío más bajo, haciendo sus productos más atractivos. La Tienda 1, en cambio, registró el costo de envío promedio más alto, lo cual puede desalentar a ciertos compradores.
#
# **Visualización sugerida: Gráfico de barras comparando el costo de envío promedio por tienda.**
#
# ###Análisis Geográfico de Ventas
# Para identificar patrones de comportamiento según ubicación, se analizó la distribución de ventas por coordenadas geográficas (latitud y longitud) de cada tienda. A través de gráficos de dispersión y mapas de calor, se observaron concentraciones importantes de ventas en áreas específicas, destacando las siguientes conclusiones:
#
# - **La Tienda 1** presenta una mayor densidad de ventas en zonas costeras, aunque tiene calificaciones más bajas y altos costos de envío.
# - **La Tienda 3** mantiene un equilibrio entre cobertura geográfica, calificaciones altas y ventas considerables, especialmente en zonas del interior.
# - **La Tienda 4**, a pesar de tener bajo ingreso, muestra un alcance amplio y costos de envío bajos, lo cual sugiere que con una mejor estrategia podría mejorar su rendimiento.
#
# Este análisis geoespacial permite comprender mejor dónde están los clientes, identificar regiones subatendidas y tomar decisiones sobre posibles reubicaciones, promociones localizadas o expansiones logísticas.
#
# ###Conclusión y Recomendación Final
# Después de analizar los diferentes factores clave, se concluye que la mejor opción para el Sr. Juan es la Tienda 3, y la tienda que debería vender es la Tienda 4.
# A continuación, se detallan las razones principales:
#
# ####**Tienda recomendada para vender:** Tienda 3
# - Altos ingresos totales, mostrando un buen volumen de ventas.
#
# - La mejor calificación promedio, lo que sugiere una base de clientes satisfechos.
#
# - Productos bien vendidos, con buena rotación y variedad.
#
# - El costo de envío más bajo, favoreciendo al consumidor final y aumentando la competitividad.
#
# ####**Tienda con peor rendimiento:** Tienda 4
# - Bajos ingresos totales, lo que indica poca actividad comercial.
#
# - Calificación promedio baja, reflejando baja satisfacción del cliente.
#
# - Poca variedad de productos vendidos, sin un producto destacado.
#
# - Aunque tiene el costo de envío más bajo, no compensa su débil desempeño general.
#
# Aunque la Tienda 1 mostró mayores ingresos, sus costos de envío elevados y menores calificaciones representan una desventaja importante. Por tanto, la Tienda 3 representa un equilibrio óptimo entre rendimiento financiero, reputación y logística, ideal para posicionar los productos del Sr. Juan.
# En contraste, la Tienda 4 es la más débil, y es donde se debe enfocar la estrategia de venta para reactivarla o venderla.
